# %%
import utils
from model import MyModel
from fasttext_vector import FastTextVector
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
input_texts = utils.read_lines("data/monument_300/train.en")
target_texts = utils.read_lines("data/monument_300/train.sparql")

# %%
model = MyModel(input_word_vector=FastTextVector("data/wiki.en.bin"), num_layers=2)
model.train(input_texts, target_texts, epochs=2, batch_size=64)
# Out:
# Number of samples: 8344
# Number of unique input words: 2519370
# Number of unique output words: 1658
# Max sequenc length for inputs: 21
# Max sequenc length for outputs: 33
# Train on 6675 samples, validate on 1669 samples
# Epoch 1/2
# 6675/6675 [==============================] - 48s 7ms/step - loss: 2.4241 - categorical_accuracy: 0.1170 - val_loss: 1.1287 - val_categorical_accuracy: 0.1712
# Epoch 2/2
# 6675/6675 [==============================] - 46s 7ms/step - loss: 1.0090 - categorical_accuracy: 0.1957 - val_loss: 0.8532 - val_categorical_accuracy: 0.2173

# %%
model.visualize()
# model.save('output/my_model.h5')
model.plot_model('output/my_model.png')
# print(model.inference("I have a dream"))

# %%
print(model.inference("how many monument does china have"))
# Out:
# ['select', 'var_a', 'var_a', 'where', 'brack_open', 'var_a', 'brack_close']
